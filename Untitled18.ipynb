# %% [markdown]
# <a href="https://colab.research.google.com/github/itzpatya-cell/python-assignment/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Assignment No. 9
# 1. Simulation of a Single Server Queue

import simpy
import random

waiting_time = []

def customer(env, name, server):
    arrival = env.now
    print(name, "arrived at", arrival)

    with server.request() as req:
        yield req

        wait = env.now - arrival
        waiting_time.append(wait)

        print(name, "started service at", env.now)

        service_time = random.randint(2, 5)
        yield env.timeout(service_time)

        print(name, "left at", env.now)

def source(env, server):
    for i in range(5):
        yield env.timeout(random.randint(1, 3))
        env.process(customer(env, "Customer " + str(i + 1), server))

env = simpy.Environment()
server = simpy.Resource(env, capacity=1)

env.process(source(env, server))
env.run()

print("\nAverage Waiting Time =", sum(waiting_time) / len(waiting_time))


# 2. Change Server Capacity to 2
server = simpy.Resource(env, capacity=2)

# 3. Change Service Time Range
service_time = random.randint(4, 6)

# 4. Display Average Waiting Time
print("Average Waiting Time =", sum(waiting_time) / len(waiting_time))
